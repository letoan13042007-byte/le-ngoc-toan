# %% [markdown]
# Viết một chương trình nhập vào một số nguyên n và in ra các chữ số đảo ngược nhau.

# %%
n = input()
print("".join(reversed(n)))
# Out:
# 4321

# %% [markdown]
# W3A2
# Hoán đổi hai số không sd biến tạm thời
# Sử dụng phép toán XOR bitwise để hoán đổi giá trị của hai biến.

# %%
a, b = map(int, input().split())
a = a ^ b
b = a ^ b
a = a ^ b
print(a, b)
# Out:
# 2 1

# %% [markdown]
# W3A3
# Kiểm tra xem một số có phải là lũy thừa của 2 hay không
# Sử dụng các toán tử bitwise để xác định xem một số có phải là lũy thừa của 2 hay không

# %%
n = int(input())
if n > 0 and (n & (n - 1)) == 0:
    print("True")
else:
    print("False")
# Out:
# True

# %% [markdown]
# W3A4 viêt chương trình chia một số m cho n, kết quả thu được làm tròn xuống

# %%
import math
n = float(input())
m = float(input())
a = m / n
print(math.floor(a))
# Out:
# 0

# %% [markdown]
# W3A5 viêt chương trình chia một số m cho n, kết quả thu được làm tròn lên

# %%
n = float(input())
m = float(input())
a = m / n
import math 
print(math.ceil(a))
# Out:
# 1

# %% [markdown]
# 6.Nhập vào một số nguyên dương x, bạn hãy kiểm tra xem x là số chẵn hay lẻ. Nếu x là số chẵn, in ra "Even". Nếu x
# là số lẻ, in ra "Odd".

# %%
x = int(input()) 
if x % 2 == 0:
   print("Even")
else:
   print("Odd")
# Out:
# Even

# %% [markdown]
# 7.Nhập vào hai số nguyên a, b. Nếu cả hai số a, b đều âm thì in ra "Yes", ngược lại in ra "No"

# %%
a ,b = map(int, input().split())
if a < 0 and b < 0: 
    print("yes")
else:
    print("no")
# Out:
# yes

# %% [markdown]
# W3A8
# [Longer string]
# Nhập vào hai chuỗi a, b gồm các chữ cái thường. In ra "True" nếu chuỗi a dài hơn chuỗi b. Ngược lại in ra "False"

# %%
a = input()
b = input()
c = len(a)
d = len (b)
if c > d :
    print("True")
else:
    print("False")
# Out:
# True

# %% [markdown]
# W3A9.Nhập vào 3 số nguyên dương a, b, c. Kiểm tra xem a, b, c có cấu thành độ dài cạnh của 1 tam giác được không.
# Nếu a, b, c cấu tạo thành được một tam giác, in ra "Yes". Ngược lại in ra "No".

# %%
a, b, c = map(int, input().split())
if a + b > c and a + c > b and b + c > a :
    print("Yes")
else :
    print("No")
# Out:
# Yes

# %% [markdown]
# W3A10.Nhập vào 4 số nguyên. In ra màn hình số nguyên lớn nhất trong 4 số.

# %%
a , b, c, d = map(int, input().split())
print(max(a, b, c, d))
# Out:
# 4

# %% [markdown]
# 11.[Phân loại tam giác]
# Nhập vào 3 số nguyên dương a,b,c là độ dài 3 cạnh của một tam giác. Kiểm tra 3 số đã nhập có tạo thành một tam giác hợp
# lệ hay không. Nếu không in ra "Không phải tam giác". Nếu có, phân loại tam giác đó là "Tam giác đều", "Tam giác cân", hay
# "Tam giác thường".

# %%
a, b, c = map(int, input().split())
if a + b > c and a + c > b and b + c > a :
    if a == b == c :
        print(" day la tam giac deu")
    elif a == b or a==c or b == c :
        print("day la tam giac can")
    else :
        print("day la tam giac thương")
else:
    print("day khong phai tam giac")

# %% [markdown]
# W3A12
# [Kiểm tra năm nhuận]
# Nhập vào một số nguyên dương n là số năm, kiểm tra xem năm đó có phải là năm nhuận hay không. Năm nhuận là năm
# chia hết cho 4 nhưng không chia hết cho 100, hoặc chia hết cho 400. Nếu là năm nhuận in ra "Yes", nếu không in ra "No"

# %%
n = int(input())
if (n % 4 == 0 and n % 100 != 0) or n % 400 ==0:
    print("Yes")
else :
    print("No")
# Out:
# Yes

# %% [markdown]
# W3A13
# [Tính tiền điện]
# Nhập vào số kWh điện tiêu thụ. Tính tiền điện theo các bậc sau: - 0-50 kWh: 1500đ/kWh - 51-100 kWh: 2000đ/kWh - 100 kWh: 3000đ/kWh

# %%
n = int(input())
if n <= 50 :
    print(n * 1500)
elif n <= 100:
    print(50*1500 + (n-50) * 2000)   
else:
    print(50 * 1500 + 50 * 2000 + (n - 100) * 3000)
# Out:
# 325000

# %% [markdown]
# W3A14
# [Giải phương trình bậc nhất]
# Nhập vào hai số thực a và b của phương trình ax + b = 0. Tìm và in ra nghiệm của phương trình, kết quả làm tròn đến số
# thập phân thứ 2. In ra "Vô nghiệm" hoặc "Vô số nghiệm" trong trường hợp tương ứng.

# %%
a, b = map(float, input().split())
x = - b / a
if a != 0 and b != 0 :
    print(round(x, 2))
elif a == 0 :
    if b == 0 :
        print("vo so nghiem")
    else:
        print("vo nghiem")
# Out:
# -1.33

# %% [markdown]
# W3A15
# [Xếp loại học lực]
# Nhập vào điểm trung bình của một học sinh và in ra học lực của học sinh đó. Xếp loại học lực theo quy tắc: - >= 8.0: Giỏi - >= 6.5: Khá - >= 5.0: Trung bình - < 5.0: Yếu

# %%
n = float(input())
if n >= 8 :
    print("gioi")
elif n >= 6.5 :
    print("kha")
elif n >= 5 :
    print("trung binh")   
else:
    print("yeu")
# Out:
# gioi

# %% [markdown]
# 16.Nhập vào một số thực: in ra kết quả làm tròn lên ,tròn xuống, làm tròn tới số nguyên gần nhất (không được sử dụng hàm
# sẵn có của pyton). Các kết quả cách nhau một dấu cách

# %%
n = float(input())

# %% [markdown]
# W3A17
# Cấp số nhân
# Cho 4 số a, b, c, d. Hãy kiểm tra xem 4 số này có thể theo thứ tự tạo thành 1 cấp số nhân với công bội nguyên theo đúng
# thứ tự a, b, c, d hay không?
# Gợi ý : Tìm công bội (b / a) nếu b chia hết cho a, sau đó lấy b nhân công bội và so sánh vs c, c nhân công bội và so sánh vs d

# %%
a, b, c, d = map(int, input().split())
if b % a == 0 :
    print(f"cong boi {b / a}")
    if (b / a) * b == c and c * (b / a) == d :
        print("day la  csn theo thu tu voi cong boi nguyen")
    else:
        print("day khong phai csn")    
else:
    print("khong phai csn theo cong boi nguyen")
# Out:
# cong boi 2.0
# day la  csn theo thu tu voi cong boi nguyen
