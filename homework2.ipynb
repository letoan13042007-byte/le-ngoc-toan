# %% [markdown]
# Bài 1: Nhập vào 2 cạnh của một hình chữ nhật. In ra màn hình diệntíchvàchu vi của nó.

# %%
a = float(input("nhap chieu dai: "))
b = float(input("nhap chieu rong: "))
chu_vi = (a + b)*2
dien_tich = a * b
print(f"chu vi la {chu_vi} ")
print(f"dien tich la {dien_tich} ")
# Out:
# chu vi la : 18.0
# dien tich la: 20.0

# %% [markdown]
# Bài 2: Nhập vào bán kính của hình tròn. In ra màn hình diện tích và chu vi của nó.

# %%
pi = 3.14
ban_kinh = float(input("nhap ban kinh"))
chu_vi = pi * 2 * ban_kinh
S = pi * ban_kinh **2
print(f"chu vi hinh tron la {chu_vi}")
print(f"dien tich hinh tron la {S}")
# Out:
# chu vi hinh tron la 18.84
# dien tich hinh tron la 28.26

# %% [markdown]
# Bài 3 : Tính tam giác: Nhâp vào ba số a,b,c bất kì. Kiểmtra xem nó có thể làđộ dài ba cạnh hay không, nếu không thì in ra màn hình 'Khong la ba canh cua mot tam giac'. Ngược lại, kiểm tra xem nó là tam giác gì: Đều, Cân, Vuông, hay Tam giác thường. Tính diện tích, chu vi của tam giác và in ra mànhình.

# %%
a, b, c = map(float, input().split())

if a + b > c and a + c > b and b + c > a and a > 0 and b > 0 and c > 0 :
    
    if a == b or b == c or a == c :
       print("day la tam giac can ")
    elif a == b and b == c :
       print("day la tam giac deu ")
    elif a**2 + b**2 == c**2 or a**2 + c**2 == b**2 or b**2 + C**2 == a**2 :
       print("day la tam giac vuong ")
    else :
       print(" day la tam giac thuong ") 

else:
   print("day khong phai la tam giac")
p = (a + b + c)/2   
S = (p*(p - a)*(p - b)*(p - c))**0.5
C = a + b + c
print(f"dien tich tam giac la {S}")
print(f"chu vi tam giac do la {C}")
# Out:
# day la tam giac vuong
# dien tich tam giac la 6.0
# chu vi tam giac do la 12.0

# %% [markdown]
# Bài 4: Viết chương trình giải phương trình bậc 1 (ax + b = 0)

# %%
a, b = map(float, input().split())
if a > 0 or a < 0 :
   print(f"Gia tri can tim la {-b/a}")
else :
   print("phuong trinh vo nghiem")
# Out:
# Gia tri can tim la -1.3333333333333333

# %% [markdown]
# Bài 5: Viết chương trình giải phương trình bậc 2 (ax2 + bx + c = 0)

# %%
a, b, c = map(float, input().split())
delta = b**2 - 4*a*c
x1 = (-b + delta**1/2) / (2 * a)
x2 = (-b - delta**1/2) / (2 * a)
x = -b/(2 * a)
if delta < 0 :
   print("phuong trinh vo nghiem")
elif delta > 0 :   
   print(f"phuong trinh co 2 nghiem phan biet {x1} va {x2}")
else :
   print(f"phuong trinh co nghiem kep {x}")
# Out:
# phuong trinh vo nghiem

# %% [markdown]
# Bài 6: Tìm giá trị lớn nhất trong 4 số a, b, c, d (a, b, c, được nhập từ bànphím).

# %%
a, b, c, d = map(float, input().split())
print(max(a, b, c, d))
# Out:
# 5.0

# %% [markdown]
# Bài 7: Tìm giá trị nhỏ nhất trong 4 số a, b, c, d (a, b, c, được nhập từ bànphím).

# %%
a, b, c, d = map(float, input().split())
print(min(a, b, c, d))
# Out:
# 3.0

# %% [markdown]
# Bài 8: Giải hệ phương trình tuyến tính:
# ax  by  m
# cx  dy  n

# %% [markdown]
# Bài 9: Nhập vào thời gian 1 công việc nào đó là x giây. Hãy chuyển đổi và viết ra màn hình số thời gian trên dưới dạng bằng bao nhiêu giờ, bao nhiêu phút, bao nhiêu giây.

# %%
x = float(input("nhap so giay hoc bai"))
h = x / 3600
m = x / 60
print(f"so gio hoc bai la {h} gio")
print(f"so phut hoc bai la {m} phut")
print(f"so giay hoc bai la {x} giay")
# Out:
# so gio hoc bai la 1.0 gio
# so phut hoc bai la 60.0 phut
# so giay hoc bai la 3600.0 giay

# %% [markdown]
# Bài 10: Nhập vào tâm và bán kính của một đường tròn. Sau đó nhập vàomộtđiểm A(x, y) bất kì và kiểm tra xem nó có thuộc đường tròn hay không?

# %%
a, b = map(float, input("nhap vao toa do tam").split())
r = float(input("ban kinh"))
c = r - (( x -a )**2 + ( y - b )**2)**(1/2)
x, y = map(float, input().split()) 
if c == 0 :
    print("co thuoc duong tron")
else :
    print("khong thuoc duong tron")
# Out:
# co thuoc duong tron

# %% [markdown]
# Bài 11: Tính x**y
#  (Với x, y là số thực)

# %%
x, y = map(float, input().split())
a = x ** y
print(a)
# Out:
# 8.0

# %%
x, y = map(float, input().split())
print(pow(x, y))
# Out:
# 8.0
